# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

plt.plot(x, y, label="line", color="blue", linestyle="__", marker="o")

# %%
import pandas as pd

df = pd.read_csv("dummy_sales_data.csv")

print(df.head())

print(df.info())

print(df.describe())
# Out:
#          Date     Product  Sales_Amount  Units_Sold Store_Location
# 0  2024-01-01      Laptop           500           5       New York
# 1  2024-01-02      Tablet           300           3         London
# 2  2024-01-03  Smartphone           200           2          Tokyo
# 3  2024-01-04     Monitor           150           1         Berlin
# 4  2024-01-05  Headphones           100           1          Paris
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            30 non-null     object
#  1   Product         30 non-null     object
#  2   Sales_Amount    30 non-null     int64
#  3   Units_Sold      30 non-null     int64
#  4   Store_Location  30 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.3+ KB
# None
#        Sales_Amount  Units_Sold
# count      30.00000   30.000000
# ...

# %%
import matplotlib.pyplot as plt

df["Date"] = pd.to_datetime(df["Date"])  # Convert Date column to datetime
df_grouped = df.groupby("Date")["Sales_Amount"].sum()  # Aggregate sales by date

plt.plot(df_grouped.index, df_grouped.values, marker="o", linestyle="-")
plt.xlabel("Date")
plt.ylabel("Total Sales Amount")
plt.title("Daily Sales Trend")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
df_grouped_products = df.groupby("Product")["Sales_Amount"].sum()

df_grouped_products.plot(kind="bar", color=["blue", "green", "red", "purple", "orange"])
plt.xlabel("Product")
plt.ylabel("Total Sales Amount")
plt.title("Total Sales by Product")
plt.show()

# %%
appl = pd.read_csv("AAPL.csv")

print(appl.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3749 entries, 0 to 3748
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3749 non-null   object
#  1   High       3749 non-null   float64
#  2   Low        3749 non-null   float64
#  3   Open       3749 non-null   float64
#  4   Close      3749 non-null   float64
#  5   Volume     3749 non-null   float64
#  6   Adj Close  3749 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 205.1+ KB
# None

# %%
appl.shape
# Out:
# (3749, 7)

# %%
appl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3749 entries, 0 to 3748
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3749 non-null   object
#  1   High       3749 non-null   float64
#  2   Low        3749 non-null   float64
#  3   Open       3749 non-null   float64
#  4   Close      3749 non-null   float64
#  5   Volume     3749 non-null   float64
#  6   Adj Close  3749 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 205.1+ KB

# %%
appl.isnull().sum()
# Out:
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
appl.nunique()
# Out:
# Date         3749
# High         3547
# Low          3573
# Open         3590
# Close        3601
# Volume       3738
# Adj Close    3674
# dtype: int64

# %%
appl.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  3749.000000  3749.000000  3749.000000  3749.000000  3.749000e+03
# mean     25.474194    24.939415    25.209072    25.216799  4.483879e+08
# std      23.634906    23.043211    23.342469    23.352043  3.973082e+08
# min       1.888929     1.791429     1.847500     1.809643  2.043060e+07
# 25%       6.857143     6.707857     6.790000     6.783928  1.440128e+08
# 50%      19.645357    19.242857    19.482143    19.445000  3.262924e+08
# 75%      34.912498    34.650002    34.712502    34.750000  6.327160e+08
# max     137.979996   130.529999   137.589996   134.179993  3.372970e+09
#
#          Adj Close
# count  3749.000000
# mean     23.669295
# std      23.341147
# min       1.548412
# 25%       5.804637
# 50%      17.087896
# 75%      32.785446
# max     133.948898

# %%
appl.dtypes
# Out:
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob  # Used to read multiple files
import os  # Used to work with file paths

# %%
folder_path = "/Users/josh/Desktop/jupy_notebooks"

# Path to folder containing CSV files
 # Change this to your actual folder path

# Get a list of all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))


df_list = [] 

for file in csv_files:
    
    temp_df = pd.read_csv(file)
    
    temp_df["Company"] = os.path.basename(file).split(".")[0]  
    
    df_list.append(temp_df)


df = pd.concat(df_list, ignore_index=True)


print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273223 entries, 0 to 273222
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Date                   272618 non-null  object
#  1   High                   272618 non-null  float64
#  2   Low                    272618 non-null  float64
#  3   Open                   272618 non-null  float64
#  4   Close                  272618 non-null  float64
#  5   Volume                 272718 non-null  float64
#  6   Adj Close              272618 non-null  float64
#  7   Company                273223 non-null  object
#  8   Symbol                 605 non-null     object
#  9   Name                   605 non-null     object
#  10  Sector                 505 non-null     object
#  11  Price                  100 non-null     float64
#  12  Change                 100 non-null     float64
#  13  % Change               100 non-null     float64
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
plt.figure(figsize=(12, 6))

# Plot closing prices for some companies
companies_to_plot = ["AAPL", "MSFT", "NVDA", "AMZN", "GOOGL"]  # Choose top 5 companies

for company in companies_to_plot:
    company_df = df[df["Company"] == company]
    plt.plot(company_df["Date"], company_df["Close"], label=company)

plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("Stock Prices Over Time (Top Tech Companies)")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Plot closing prices for some companies
companies_to_plot = ["AAPL", "MSFT", "NVDA", "AMZN", "GOOGL"]  # Choose top 5 companies

for company in companies_to_plot:
    company_df = df[df["Company"] == company]
    plt.plot(company_df["Date"], company_df["Close"], label=company)

plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("Stock Prices Over Time (Top Tech Companies)")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))

avg_prices = df.groupby("Company")["Close"].mean().sort_values(ascending=False)[:10]  # Top 10 companies
avg_prices.plot(kind="bar", color="skyblue")

plt.xlabel("Company")
plt.ylabel("Average Closing Price (USD)")
plt.title("Top 10 Companies by Average Stock Price")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 5))

df["Close"].hist(bins=50, color="purple", edgecolor="black")

plt.xlabel("Stock Price (USD)")
plt.ylabel("Frequency")
plt.title("Distribution of Stock Prices")
plt.grid(True)
plt.show()

# %%
# !pip install seaborn

# %%
market_caps = {"AAPL": 2500, "MSFT": 2300, "NVDA": 1800, "GOOGL": 1600, "AMZN": 1500}  # In billions

plt.figure(figsize=(8, 8))
plt.pie(market_caps.values(), labels=market_caps.keys(), autopct="%1.1f%%", colors=["gold", "blue", "green", "red", "purple"])
plt.title("Market Share of Top Tech Companies")
plt.show()
